# %% [markdown]
# <a href="https://colab.research.google.com/github/rathans48/Machine-Learning/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
print("Lane: Structured Content Archetype Clustering")
print("\nI picked this one because I feel I this is the kind of thing I like to do as an ML Engineer.\nIt involves grouping based on behaviour, mapping and visualizing said groups.\nIt also involves using ML techniques that I have read in theory but have never implemented.\nThis is my justification for choosing Lane 3.")
# Out:
# Lane: Structured Content Archetype Clustering
#
# I picked this one because I feel I this is the kind of thing I like to do as an ML Engineer.
# It involves grouping based on behaviour, mapping and visualizing said groups.
# It also involves using ML techniques that I have read in theory but have never implemented.
# This is my justification for choosing Lane 3.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
print("Decision Improvement: SEO involves going through hundreds of pages and reviewing them.\nBy implementing this, the task can be less burdened since the pages will be clustered into simple named archetypes.\nBased on the cluster, you can have a general idea of how the page is performing without having to perform any complex tasks.")
print("\nAction: A content strategist or SEO reviewer with limited weekly review capcity.")
print("\nCost of Wrong Call: Wrong clustering can lead to a 'hidden gem' being clustered as 'weak' which leads to pruning.\nA declining page miscalculated as a champion means the team leaves it as it keeps losing visibility.\nBasically it involves the technique wrongfully clustering specific content.\nIt can lead to mistakes but not anything that is high of risk.")
# Out:
# Decision Improvement: SEO involves going through hundreds of pages and reviewing them.
# By implementing this, the task can be less burdened since the pages will be clustered into simple named archetypes.
# Based on the cluster, you can have a general idea of how the page is performing without having to perform any complex tasks.
#
# Action: A content strategist or SEO reviewer with limited weekly review capcity.
#
# Cost of Wrong Call: Wrong clustering can lead to a 'hidden gem' being clustered as 'weak' which leads to pruning.
# A declining page miscalculated as a champion means the team leaves it as it keeps losing visibility.
# Basically it involves the technique wrongfully clustering specific content.
# It can lead to mistakes but not anything that is high of risk.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd

df = pd.read_csv('content_refresh_anonymized.csv')

print(df.shape)
print(df['impressions_90d'].describe(percentiles=[.5, .9, .99]))
print(df['trend_direction'].value_counts())
print(df['position_tier'].value_counts())
print("\nFrom the impressions_90d 50%, 90%, 99% values it is clear that traffic volume is spread widely. This spread is what clustering requires so as to find a real separation.")
print("\nTrend behaviour shows data is already split across five groups like down, stable, up, new, and flat. This shows that different groups exist even before anything has been done.")
print("\n24% of pages sit just below page 1 (striking tier), distinct from both top performers (top_3/page_1, 47% combined) and buried pages (deep, 4%). That's a natural candidate archetype worth testing for.")
# Out:
#      <input type="file" id="files-be2b59cd-0f5f-4f54-986c-9438046242b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be2b59cd-0f5f-4f54-986c-9438046242b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("What I can claim:\nThese are observed, descriptive groupings based on real traffic, position, and trend measurements from the last 90 days.\nThe clusters are a decision-support lens, a way to triage review priority, not a definitive judgment on any single page.\nCluster patterns are directional [pages in this group tend to have low CTR and declining trend], useful for prioritizing review, not a certainty about any individual case.")
print("\nWhat I will never claim:\nThat these clusters prove why a page is performing a certain way (no causal claim, I didn't run an experiment).\nThat this predicts or explains Google's ranking algorithm.\nThat moving a page between archetypes [e.g. rewriting a stale page] will cause it to recover, that would require a controlled test, which this data can't provide.\nThat the clusters are stable truths rather than a lens I chose, I'll check cluster stability on a re-run, but even stable clusters describe patterns, not laws.")
# Out:
# What I can claim:
# These are observed, descriptive groupings based on real traffic, position, and trend measurements from the last 90 days.
# The clusters are a decision-support lens, a way to triage review priority, not a definitive judgment on any single page.
# Cluster patterns are directional [pages in this group tend to have low CTR and declining trend], useful for prioritizing review, not a certainty about any individual case.
#
# What I will never claim:
# That these clusters prove why a page is performing a certain way (no causal claim, I didn't run an experiment).
# That this predicts or explains Google's ranking algorithm.
# That moving a page between archetypes [e.g. rewriting a stale page] will cause it to recover, that would require a controlled test, which this data can't provide.
# That the clusters are stable truths rather than a lens I chose, I'll check cluster stability on a re-run, but even stable clusters describe patterns, not laws.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
